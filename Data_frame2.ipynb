# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv", parse_dates = ["Start Date", "Last Login Time"] ) # this is an alternative/better way to do what the next two lines of code do
df["Start Date"] = pd.to_datetime(df["Start Date"])
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)

# %%
df.info() # good practice to see if we can optimize the data, looking at amount of nonnull values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df["Start Date"].head(3) ## you can see it is a string right now
# Out:
# 0     8/6/1993
# 1    3/31/1996
# 2    4/23/1993
# Name: Start Date, dtype: object

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"]).head(3) # using pandas library we will overwrite the old column and change the type of the column

# %%
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"]).head(3) # NOTE FOR EMPTY CELLS IN THIS COLUMN PANDAS WIILL INPUT TODAYS DATE

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
df["Gender"] = df["Gender"].astype("category")

# %%
df.info() ## now looking at the memory after adjustments
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           3 non-null datetime64[ns]
# Last Login Time      3 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %% [markdown]
# Filter a dataframe based on a condition

# %%
df[df["Gender"] == "Male"] ## critical to use double equal signs to make it retrun if it is true or false WILL ONLY EXTRACT IF IT IS A MALE
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2018-07-04 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2018-07-04 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2018-07-04 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2018-07-04 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2018-07-04 01:35:00  115163   10.125
# 12     Brandon   Male 1980-12-01 2018-07-04 01:08:00  112807   17.492
# 13        Gary   Male 2008-01-27 2018-07-04 23:40:00  109831    5.831
# 16      Jeremy   Male 2010-09-21 2018-07-04 05:56:00   90370    7.369
# 17       Shawn   Male 1986-12-07 2018-07-04 19:45:00  111737    6.414
# 21     Matthew   Male 1995-09-05 2018-07-04 02:12:00  100612   13.645
# 23         NaN   Male 2012-06-14 2018-07-04 16:19:00  125792    5.042
# 24        John   Male 1992-07-01 2018-07-04 22:08:00   97950   13.873
# ...

# %%
extract = df["Team"] == "Finance" ### storing the boolean list of

df[extract].head() ## this wil return our df dataframe but where team is only equal to finance
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2018-07-04 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2018-07-04 13:00:00  138705    9.340
# 7         NaN  Female 2015-07-20 2018-07-04 10:43:00   45906   11.598
# 14   Kimberly  Female 1999-01-14 2018-07-04 07:13:00   41426   14.543
# 46      Bruce    Male 2009-11-28 2018-07-04 22:47:00  114796    6.796
#
#     Senior Management     Team
# 2               False  Finance
# 3                True  Finance
# 7                True  Finance
# 14               True  Finance
# 46              False  Finance

# %%
df[df["Senior Management"]].head() ##senior management was already boolean, and will return what is True
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-07-04 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-07-04 06:53:00   61933    4.170
# 3      Jerry    Male 2005-03-04 2018-07-04 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-07-04 16:47:00  101004    1.389
# 6       Ruby  Female 1987-08-17 2018-07-04 16:20:00   65476   10.012
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 6               True          Product

# %%
extractt = df["Team"] != "Marketing" #for finding what is not equal
df[extractt].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1     Thomas    Male 1996-03-31 2018-07-04 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-07-04 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-07-04 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-07-04 16:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18 2018-07-04 01:35:00  115163   10.125
#
#    Senior Management             Team
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
extracttt = df["Salary"] > 110000
df[extracttt].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2018-07-04 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2018-07-04 13:00:00  138705    9.340
# 5      Dennis    Male 1987-04-18 2018-07-04 01:35:00  115163   10.125
# 9     Frances  Female 2002-08-08 2018-07-04 06:51:00  139852    7.524
# 12    Brandon    Male 1980-12-01 2018-07-04 01:08:00  112807   17.492
#
#     Senior Management                  Team
# 2               False               Finance
# 3                True               Finance
# 5               False                 Legal
# 9                True  Business Development
# 12               True       Human Resources

# %%
df["Start Date"] <= "1985-01-01"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10      True
# 11     False
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28      True
# 29     False
#        ...
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978     True
# 979    False
# 980    False
# 981    False
# 982     True
# 983     True
# 984    False
# 985     True
# 986     True
# 987    False
# 988    False
# 989    False
# 990    False
# 991    False
# 992    False
# 993    False
# 994    False
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Name: Start Date, Length: 1000, dtype: bool

# %% [markdown]
# Multiple condition filtering

# %%
mask1 = df["Gender"] == "Male"
mask2 = df["Team"] == "Marketing"
df[mask1 & mask2] # only pulls in rows where both conditions are satisfied

# %%
import pandas as pd
df = pd.read_csv("employees.csv", parse_dates = ["Start Date", "Last Login Time"] ) # this is an alternative/better way to do what the next two lines of code do
df["Start Date"] = pd.to_datetime(df["Start Date"])
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-07-04 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-07-04 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-07-04 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask1 = df["Senior Management"]
mask2 = df["Start Date"] < "1990-01-01"

df[mask1 | mask2] #only pulls 1 OR the other

# %%
mask1 = df["First Name"] == "Robert"### NOTE THESE ARE BOOLEAN SERIES
mask2 = df["Team"] == "Client Services"
mask3 = df["Start Date"] > "2016-06-01"

df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2018-07-04 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2018-07-04 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2018-07-04 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2018-07-04 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# Is IN, completes a filter process of multiple values, different than creating  multiple boolean series like we did above in each variable

# %%
df["Team"].isin(["Legal","Sales","Product"]).head() ## this method, isin is going to compare values in the argument to what is in the column specified and it will return boolean
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Team, dtype: bool

# %% [markdown]
# Isnull or Notnull - another way we can generate a bolean series to filter later

# %%
df["Gender"].notnull().head() # true where it is null
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Gender, dtype: bool

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-07-04 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-07-04 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-07-04 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-07-04 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-07-04 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df.dropna()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2018-07-04 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2018-07-04 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2018-07-04 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2018-07-04 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2018-07-04 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2018-07-04 16:20:00   65476   10.012
# 8       Angela  Female 2005-11-22 2018-07-04 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2018-07-04 06:51:00  139852    7.524
# 11       Julie  Female 1997-10-26 2018-07-04 15:19:00  102508   12.637
# 12     Brandon    Male 1980-12-01 2018-07-04 01:08:00  112807   17.492
# 13        Gary    Male 2008-01-27 2018-07-04 23:40:00  109831    5.831
# 14    Kimberly  Female 1999-01-14 2018-07-04 07:13:00   41426   14.543
# ...

# %%
df = pd.DataFrame({'Team': ['Finance', 'Finally', 'Foo']})

# %%
df
# Out:
#       Team
# 0  Finance
# 1  Finally
# 2      Foo

# %%
df[df.Team.str.contains('Fin')]
# Out:
#       Team
# 0  Finance
# 1  Finally
