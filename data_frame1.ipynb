# %%
## dimensional -- how many points of information do you need to get a specific peice of data
## 1 point of reference will not help find the data
## number of points we need is the number of dimensions 
## panda datafram is two dimensions
## it is a panda objet

# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")

# %%
nba.head(1)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %%
## new data

# %%
rev = pd.read_csv("revenue.csv", index_col = "Date")

# %%
s = pd.Series([1, 2, 3])

s.sum()
# Out:
# 6

# %%
rev.sum(axis = 1) ## with index, it moves across rows to get sum, so we can change it to 1 or  =columns , so it would now be calculating off date
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.Name ## just need to put name of column to extract it, it extracts it as a series
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
# ...

# %%
nba.Number

Output = None  #just stops data from returning below

# %%
nba["Name"] # this is better call columns because the above method can't call column names with space, this method is a lot less prone to error
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
# ...

# %%
nba["Salary"] # it is case sensitive
# Out:
# 0       7730337.0
# 1       6796117.0
# 2             NaN
# 3       1148640.0
# 4       5000000.0
# 5      12000000.0
# 6       1170960.0
# 7       2165160.0
# 8       1824360.0
# 9       3431040.0
# 10      2569260.0
# 11      6912869.0
# 12      3425510.0
# 13      1749840.0
# 14      2616975.0
# 15      3425510.0
# 16       845059.0
# 17      1500000.0
# 18      1335480.0
# 19      6300000.0
# 20      1599840.0
# 21       134215.0
# 22      1500000.0
# 23     19689000.0
# 24      1140240.0
# 25       947276.0
# 26       981348.0
# 27       947276.0
# 28       947276.0
# 29     11235955.0
#           ...
# 428     8042895.0
# 429      625093.0
# 430      947276.0
# 431     6980802.0
# 432     2894059.0
# 433     6000000.0
# 434     5016000.0
# 435     3075880.0
# 436     4236287.0
# 437     2525160.0
# 438      525093.0
# 439     1415520.0
# 440     2854940.0
# 441     2637720.0
# 442     4775000.0
# 443     2658240.0
# 444     9463484.0
# 445     3777720.0
# 446    12000000.0
# ...

# %%
nba["Name"].head() #going to get the column as a series and you can call an attribute in sequence
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
type(nba["Name"]) # returns object
# Out:
# pandas.core.series.Series

# %%
## Next we will look at working with multiple columns

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba[      ["Name", "Team"]      ] #when we extracting two or more columns we get a NEW datafram as the output not a series
# Out:
#                         Name                    Team
# 0              Avery Bradley          Boston Celtics
# 1                Jae Crowder          Boston Celtics
# 2               John Holland          Boston Celtics
# 3                R.J. Hunter          Boston Celtics
# 4              Jonas Jerebko          Boston Celtics
# 5               Amir Johnson          Boston Celtics
# 6              Jordan Mickey          Boston Celtics
# 7               Kelly Olynyk          Boston Celtics
# 8               Terry Rozier          Boston Celtics
# 9               Marcus Smart          Boston Celtics
# 10           Jared Sullinger          Boston Celtics
# 11             Isaiah Thomas          Boston Celtics
# 12               Evan Turner          Boston Celtics
# 13               James Young          Boston Celtics
# 14              Tyler Zeller          Boston Celtics
# 15          Bojan Bogdanovic           Brooklyn Nets
# 16              Markel Brown           Brooklyn Nets
# ...

# %%
nba[      ["Team", "Name"]      ] ## This will return the new dataframe, but column order will change
# Out:
#                        Team                     Name
# 0            Boston Celtics            Avery Bradley
# 1            Boston Celtics              Jae Crowder
# 2            Boston Celtics             John Holland
# 3            Boston Celtics              R.J. Hunter
# 4            Boston Celtics            Jonas Jerebko
# 5            Boston Celtics             Amir Johnson
# 6            Boston Celtics            Jordan Mickey
# 7            Boston Celtics             Kelly Olynyk
# 8            Boston Celtics             Terry Rozier
# 9            Boston Celtics             Marcus Smart
# 10           Boston Celtics          Jared Sullinger
# 11           Boston Celtics            Isaiah Thomas
# 12           Boston Celtics              Evan Turner
# 13           Boston Celtics              James Young
# 14           Boston Celtics             Tyler Zeller
# 15            Brooklyn Nets         Bojan Bogdanovic
# 16            Brooklyn Nets             Markel Brown
# ...

# %%
nba[["Number","College"]].head(3)
# Out:
#    Number            College
# 0     0.0              Texas
# 1    99.0          Marquette
# 2    30.0  Boston University

# %%
select = ["Salary", "Team", "Name"] # you can create a list in python, but if colums mattch up in will return these columns from the dataset, a little cleaner look
nba[select]
# Out:
#          Salary                    Team                     Name
# 0     7730337.0          Boston Celtics            Avery Bradley
# 1     6796117.0          Boston Celtics              Jae Crowder
# 2           NaN          Boston Celtics             John Holland
# 3     1148640.0          Boston Celtics              R.J. Hunter
# 4     5000000.0          Boston Celtics            Jonas Jerebko
# 5    12000000.0          Boston Celtics             Amir Johnson
# 6     1170960.0          Boston Celtics            Jordan Mickey
# 7     2165160.0          Boston Celtics             Kelly Olynyk
# 8     1824360.0          Boston Celtics             Terry Rozier
# 9     3431040.0          Boston Celtics             Marcus Smart
# 10    2569260.0          Boston Celtics          Jared Sullinger
# 11    6912869.0          Boston Celtics            Isaiah Thomas
# 12    3425510.0          Boston Celtics              Evan Turner
# ...

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba["Sport"] = "Basketball"  ## this will change everything to Basketbal in this new column  ## creating a new column, be sure to not make a new name as it will duplicate

# %%
nba.head(3) ## see sport is on the end
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba["League"] = "National Basketball Association"
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport                           League
# 0              Texas  7730337.0  Basketball  National Basketball Association
# 1          Marquette  6796117.0  Basketball  National Basketball Association
# 2  Boston University        NaN  Basketball  National Basketball Association

# %%
nba.insert(3, column = "Sports", value = "Basketball") #perm. modifies dataframe , inputs new column in specific location

# %%
nba.head(3)
# Out:
#             Name            Team  Number      Sports Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
#
#    Weight            College     Salary       Sport  \
# 0   180.0              Texas  7730337.0  Basketball
# 1   235.0          Marquette  6796117.0  Basketball
# 2   205.0  Boston University        NaN  Basketball
#
#                             League
# 0  National Basketball Association
# 1  National Basketball Association
# 2  National Basketball Association

# %%
## Broadcasting Operations

# %%
nba["Age"].add(5)
# Out:
# 0      30.0
# 1      30.0
# 2      32.0
# 3      27.0
# 4      34.0
# 5      34.0
# 6      26.0
# 7      30.0
# 8      27.0
# 9      27.0
# 10     29.0
# 11     32.0
# 12     32.0
# 13     25.0
# 14     31.0
# 15     32.0
# 16     29.0
# 17     33.0
# 18     26.0
# 19     37.0
# 20     27.0
# 21     31.0
# 22     28.0
# 23     33.0
# 24     26.0
# 25     31.0
# 26     30.0
# 27     31.0
# 28     33.0
# 29     32.0
#        ...
# 428    30.0
# 429    28.0
# 430    29.0
# 431    32.0
# 432    28.0
# 433    33.0
# 434    39.0
# 435    29.0
# 436    30.0
# 437    29.0
# 438    28.0
# 439    31.0
# 440    35.0
# 441    25.0
# 442    33.0
# 443    28.0
# 444    29.0
# 445    25.0
# 446    29.0
# 447    28.0
# 448    31.0
# 449    28.0
# 450    33.0
# 451    31.0
# 452    25.0
# 453    31.0
# 454    29.0
# 455    31.0
# 456    31.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
nba["Age"] + 5 ## adding a number to object, the column. It is adding 5 to every value in the series, pandas knows what to do
# Out:
# 0      30.0
# 1      30.0
# 2      32.0
# 3      27.0
# 4      34.0
# 5      34.0
# 6      26.0
# 7      30.0
# 8      27.0
# 9      27.0
# 10     29.0
# 11     32.0
# 12     32.0
# 13     25.0
# 14     31.0
# 15     32.0
# 16     29.0
# 17     33.0
# 18     26.0
# 19     37.0
# 20     27.0
# 21     31.0
# 22     28.0
# 23     33.0
# 24     26.0
# 25     31.0
# 26     30.0
# 27     31.0
# 28     33.0
# 29     32.0
#        ...
# 428    30.0
# 429    28.0
# 430    29.0
# 431    32.0
# 432    28.0
# 433    33.0
# 434    39.0
# 435    29.0
# 436    30.0
# 437    29.0
# 438    28.0
# 439    31.0
# 440    35.0
# 441    25.0
# 442    33.0
# 443    28.0
# 444    29.0
# 445    25.0
# 446    29.0
# 447    28.0
# 448    31.0
# 449    28.0
# 450    33.0
# 451    31.0
# 452    25.0
# 453    31.0
# 454    29.0
# 455    31.0
# 456    31.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
nba["Salary"] - 500000
# Out:
# 0       7230337.0
# 1       6296117.0
# 2             NaN
# 3        648640.0
# 4       4500000.0
# 5      11500000.0
# 6        670960.0
# 7       1665160.0
# 8       1324360.0
# 9       2931040.0
# 10      2069260.0
# 11      6412869.0
# 12      2925510.0
# 13      1249840.0
# 14      2116975.0
# 15      2925510.0
# 16       345059.0
# 17      1000000.0
# 18       835480.0
# 19      5800000.0
# 20      1099840.0
# 21      -365785.0
# 22      1000000.0
# 23     19189000.0
# 24       640240.0
# 25       447276.0
# 26       481348.0
# 27       447276.0
# 28       447276.0
# 29     10735955.0
#           ...
# 428     7542895.0
# 429      125093.0
# 430      447276.0
# 431     6480802.0
# 432     2394059.0
# 433     5500000.0
# 434     4516000.0
# 435     2575880.0
# 436     3736287.0
# 437     2025160.0
# 438       25093.0
# 439      915520.0
# 440     2354940.0
# 441     2137720.0
# 442     4275000.0
# 443     2158240.0
# 444     8963484.0
# 445     3277720.0
# 446    11500000.0
# ...

# %%
nba["Weight in Kilograms"] = nba["Weight"] * 0.54 # adds column that has specifc way to be made

# %%
nba.head(3)
# Out:
#             Name            Team  Number      Sports Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
#
#    Weight            College     Salary       Sport  \
# 0   180.0              Texas  7730337.0  Basketball
# 1   235.0          Marquette  6796117.0  Basketball
# 2   205.0  Boston University        NaN  Basketball
#
#                             League  Weight in Kilograms
# 0  National Basketball Association                 97.2
# 1  National Basketball Association                126.9
# 2  National Basketball Association                110.7

# %%
nba["Team"].value_counts() #counts number of values
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Indiana Pacers            15
# Portland Trail Blazers    15
# Houston Rockets           15
# Utah Jazz                 15
# Phoenix Suns              15
# Charlotte Hornets         15
# Miami Heat                15
# Denver Nuggets            15
# Los Angeles Lakers        15
# Washington Wizards        15
# San Antonio Spurs         15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Sacramento Kings          15
# Philadelphia 76ers        15
# Oklahoma City Thunder     15
# Dallas Mavericks          15
# Boston Celtics            15
# Toronto Raptors           15
# Chicago Bulls             15
# Cleveland Cavaliers       15
# Detroit Pistons           15
# Brooklyn Nets             15
# Atlanta Hawks             15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
nba["Position"].value_counts().head(1)
# Out:
# SG    102
# Name: Position, dtype: int64

# %%
nba["Salary"].value_counts()
# Out:
# 947276.0      31
# 845059.0      18
# 525093.0      13
# 981348.0       6
# 1100602.0      5
# 16407500.0     5
# 5000000.0      5
# 12000000.0     5
# 8000000.0      5
# 4000000.0      5
# 3000000.0      4
# 7000000.0      4
# 2814000.0      4
# 1000000.0      4
# 19689000.0     4
# 200600.0       3
# 8500000.0      3
# 2500000.0      3
# 1015421.0      3
# 2854940.0      3
# 13500000.0     3
# 5543725.0      3
# 2288205.0      2
# 1270964.0      2
# 2900000.0      2
# 1007026.0      2
# 111444.0       2
# 13000000.0     2
# 1500000.0      2
# 1842000.0      2
#               ..
# 2239800.0      1
# 1474440.0      1
# 19688000.0     1
# 7900000.0      1
# 2008748.0      1
# 13800000.0     1
# 2841960.0      1
# 1404600.0      1
# 1584480.0      1
# 273038.0       1
# 9213483.0      1
# 3272091.0      1
# 3075880.0      1
# 2250000.0      1
# 4626960.0      1
# 1304520.0      1
# 12100000.0     1
# 7500000.0      1
# 295327.0       1
# 2836186.0      1
# 6486486.0      1
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-eae9a31b0707> in <module>()
# ----> 1 nba[["Weight","Salary"]].value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
nba.dropna()
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# ...

# %%
nba.dropna(how= "all") ## removes rows were all are null
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.dropna(how = "all").tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba.dropna(axis= "columns").tail() ## remove any columns that have null valeus
# Out:
# Empty DataFrame
# Columns: []
# Index: [453, 454, 455, 456, 457]

# %%
nba.dropna(subset = ["Salary"])## will only drop the rows that are NA in the specified column
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# ...

# %% [markdown]
# Fill in null values with fillna()

# %%
nba.fillna(0) ## all nan's turnt to 0 (note will not adjust datatypes)
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba["Salary"].fillna(0, inplace = True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba["College"].fillna("No College", inplace = True)

# %% [markdown]
# astype() method, you cant use it unless there are NO NaN values

# %%
nba.dropna(how = "all")
nba["Salary"].fillna(0, inplace = True)
nba["College"].fillna("No College", inplace = True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4         No College  5000000.0

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     458 non-null object
# Salary      458 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba["Salary"] = nba["Salary"].astype("int") # change column data type

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4         No College  5000000

# %%
nba["Number"].fillna(0, inplace = True)

nba["Number"] = nba["Number"].astype("int")

# %% [markdown]
# Category is a dataype only in pandas , it is used for a small type of data / unique values against a large dataset

# %%
nba["Position"].nunique() # we have five unique values in position column, so ideal to turn this into a Category, we will have 5 objets apposed to 450000 strings
# Out:
# 5

# %%
nba["Position"] = nba["Position"].astype("category")

# %%
nba.info() #note that the memory is less
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      458 non-null int32
# Position    457 non-null category
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     458 non-null object
# Salary      458 non-null int32
# dtypes: category(1), float64(2), int32(2), object(4)
# memory usage: 25.8+ KB

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF  29.0   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4         No College  5000000

# %%
nba.sort_values("Name", ascending = "false").head() #default is it will sort the data by the column specified and ascending order
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls       0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic       0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets       9       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves      33       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks      15        C  30.0   6-10
#
#      Weight         College    Salary
# 152   161.0          Oregon   2250000
# 356   220.0         Arizona   4171680
# 328   210.0        Kentucky    525093
# 404   237.0  Michigan State   1938840
# 312   245.0         Florida  12000000

# %%
nba.sort_values("Salary",na_position = "first") # puts NA's on top or you could make them on bottom
# Out:
#                        Name                    Team  Number Position   Age  \
# 457                     NaN                     NaN       0      NaN   NaN
# 2              John Holland          Boston Celtics      30       SG  27.0
# 397            Axel Toupane          Denver Nuggets       6       SG  23.0
# 171           Dahntay Jones     Cleveland Cavaliers      30       SG  35.0
# 409              Greg Smith  Minnesota Timberwolves       4       PF  25.0
# 353           Dorell Wright              Miami Heat      11       SF  30.0
# 350           Briante Weber              Miami Heat      12       PG  23.0
# 46              Elton Brand      Philadelphia 76ers      42       PF  37.0
# 264           Jordan Farmar       Memphis Grizzlies       4       PG  29.0
# 269            Ray McCallum       Memphis Grizzlies       5       PG  24.0
# 270          Xavier Munford       Memphis Grizzlies      14       PG  24.0
# ...

# %%
nba.sort_values("Salary", ascending = False, na_position = "first") # puts NA's on top or you could make them on bottom and you can then still have the ascending features work
# Out:
#                        Name                    Team  Number Position   Age  \
# 109             Kobe Bryant      Los Angeles Lakers      24       SF  37.0
# 169            LeBron James     Cleveland Cavaliers      23       SF  31.0
# 33          Carmelo Anthony         New York Knicks       7       SF  32.0
# 251           Dwight Howard         Houston Rockets      12        C  30.0
# 339              Chris Bosh              Miami Heat       1       PF  32.0
# 100              Chris Paul    Los Angeles Clippers       3       PG  31.0
# 414            Kevin Durant   Oklahoma City Thunder      35       SF  27.0
# 164            Derrick Rose           Chicago Bulls       1       PG  27.0
# 349             Dwyane Wade              Miami Heat       3       SG  34.0
# 23              Brook Lopez           Brooklyn Nets      11        C  28.0
# 98           DeAndre Jordan    Los Angeles Clippers       6        C  27.0
# ...

# %%
nba.sort_values(["Team", "Name"]) # sorts the team then the name alphabetically
# Out:
#                  Name                Team  Number Position   Age Height  \
# 312        Al Horford       Atlanta Hawks      15        C  30.0   6-10
# 318   Dennis Schroder       Atlanta Hawks      17       PG  22.0    6-1
# 323       Jeff Teague       Atlanta Hawks       0       PG  27.0    6-2
# 309     Kent Bazemore       Atlanta Hawks      24       SF  26.0    6-5
# 311      Kirk Hinrich       Atlanta Hawks      12       SG  35.0    6-4
# 313    Kris Humphries       Atlanta Hawks      43       PF  31.0    6-9
# 314       Kyle Korver       Atlanta Hawks      26       SG  35.0    6-7
# 317   Lamar Patterson       Atlanta Hawks      13       SG  24.0    6-5
# 316      Mike Muscala       Atlanta Hawks      31       PF  24.0   6-11
# 319        Mike Scott       Atlanta Hawks      32       PF  27.0    6-8
# 315      Paul Millsap       Atlanta Hawks       4       PF  31.0    6-8
# 320   Thabo Sefolosha       Atlanta Hawks      25       SF  32.0    6-7
# ...

# %%
nba.sort_values(["Team", "Name"], ascending = [True, False]) ## makes team ascending and name descending
# Out:
#                  Name                Team  Number Position   Age Height  \
# 322    Walter Tavares       Atlanta Hawks      22        C  24.0    7-3
# 310  Tim Hardaway Jr.       Atlanta Hawks      10       SG  24.0    6-6
# 321    Tiago Splitter       Atlanta Hawks      11        C  31.0   6-11
# 320   Thabo Sefolosha       Atlanta Hawks      25       SF  32.0    6-7
# 315      Paul Millsap       Atlanta Hawks       4       PF  31.0    6-8
# 319        Mike Scott       Atlanta Hawks      32       PF  27.0    6-8
# 316      Mike Muscala       Atlanta Hawks      31       PF  24.0   6-11
# 317   Lamar Patterson       Atlanta Hawks      13       SG  24.0    6-5
# 314       Kyle Korver       Atlanta Hawks      26       SG  35.0    6-7
# 313    Kris Humphries       Atlanta Hawks      43       PF  31.0    6-9
# 311      Kirk Hinrich       Atlanta Hawks      12       SG  35.0    6-4
# 309     Kent Bazemore       Atlanta Hawks      24       SF  26.0    6-5
# ...

# %%
nba.sort_values(["Team", "Salary","Name"])
# Out:
#                  Name                Team  Number Position   Age Height  \
# 317   Lamar Patterson       Atlanta Hawks      13       SG  24.0    6-5
# 316      Mike Muscala       Atlanta Hawks      31       PF  24.0   6-11
# 313    Kris Humphries       Atlanta Hawks      43       PF  31.0    6-9
# 322    Walter Tavares       Atlanta Hawks      22        C  24.0    7-3
# 310  Tim Hardaway Jr.       Atlanta Hawks      10       SG  24.0    6-6
# 318   Dennis Schroder       Atlanta Hawks      17       PG  22.0    6-1
# 309     Kent Bazemore       Atlanta Hawks      24       SF  26.0    6-5
# 311      Kirk Hinrich       Atlanta Hawks      12       SG  35.0    6-4
# 319        Mike Scott       Atlanta Hawks      32       PF  27.0    6-8
# 320   Thabo Sefolosha       Atlanta Hawks      25       SF  32.0    6-7
# 314       Kyle Korver       Atlanta Hawks      26       SG  35.0    6-7
# 323       Jeff Teague       Atlanta Hawks       0       PG  27.0    6-2
# ...

# %%
nba.sort_index()
# in place makes it true
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics       0       PG  25.0
# 1                Jae Crowder          Boston Celtics      99       SF  25.0
# 2               John Holland          Boston Celtics      30       SG  27.0
# 3                R.J. Hunter          Boston Celtics      28       SG  22.0
# 4              Jonas Jerebko          Boston Celtics       8       PF  29.0
# 5               Amir Johnson          Boston Celtics      90       PF  29.0
# 6              Jordan Mickey          Boston Celtics      55       PF  21.0
# 7               Kelly Olynyk          Boston Celtics      41        C  25.0
# 8               Terry Rozier          Boston Celtics      12       PG  22.0
# 9               Marcus Smart          Boston Celtics      36       PG  22.0
# 10           Jared Sullinger          Boston Celtics       7        C  24.0
# ...

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF  29.0   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4         No College  5000000

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF  29.0   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4         No College  5000000

# %% [markdown]
# .rank() method

# %%
nba = pd.read_csv("nba.csv").dropna(how = "all")
nba["Salary"] = nba["Salary"].fillna(0).astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Salary Rank"]  = nba["Salary"].rank(ascending = False).astype(int)
nba.head(3)
# tends to rank ascending paremeter
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary  Salary Rank
# 0              Texas  7730337           97
# 1          Marquette  6796117          110
# 2  Boston University        0          452

# %%
nba.sort_values(by = "Salary", ascending = False).head(3)
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
#
#      Weight   College    Salary  Salary Rank
# 109   212.0       NaN  25000000            1
# 169   250.0       NaN  22970500            2
# 33    240.0  Syracuse  22875000            3
